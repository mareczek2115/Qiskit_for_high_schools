# %%
# %matplotlib inline
from qiskit import QuantumCircuit
from qiskit.compiler import transpile
from qiskit.transpiler import PassManager
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, IBMQ
from qiskit.tools.monitor import backend_overview, backend_monitor
from qiskit.compiler import transpile, assemble
from qiskit.visualization import *
from qiskit.transpiler import *
from qiskit.converters import circuit_to_dag
from qiskit.tools.visualization import dag_drawer
import pprint

# %% [markdown]
# Transpilation consists of several circuit transformatins - known as passes.
# Pass manager schedules the passes and allows them to communicate with each other by providing a shared space.
# Thanks to this transpiler is opened for optimizations.
# DAG = Directed Acyclic Graph
# DAG is the internal Qiskit representation of circuit.

# %%
provider = IBMQ.load_account()
# Out:
# C:\Anaconda3\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# ibmqfactory.load_account:WARNING:2020-11-17 09:15:28,223: Credentials are already in use. The existing account in the session will be replaced.

# %% [markdown]
# # How to get most of NISQ computers with Qiskit?
#
# ## Tomasz Stopa
#
# ## IBM

# %%
backend_overview()
# Out:
# ibmq_essex                   ibmq_burlington              ibmq_london
# ----------                   ---------------              -----------
# Num. Qubits:  5              Num. Qubits:  5              Num. Qubits:  5
# Pending Jobs: 3              Pending Jobs: 6              Pending Jobs: 21
# Least busy:   False          Least busy:   False          Least busy:   False
# Operational:  True           Operational:  True           Operational:  True
# Avg. T1:      85.0           Avg. T1:      83.5           Avg. T1:      68.3
# Avg. T2:      131.8          Avg. T2:      57.2           Avg. T2:      75.2
#
#
#
# ibmq_ourense                ibmq_vigo                    ibmqx2
# ------------                ---------                    ------
# Num. Qubits:  5             Num. Qubits:  5              Num. Qubits:  5
# Pending Jobs: 2             Pending Jobs: 10             Pending Jobs: 37
# Least busy:   True          Least busy:   False          Least busy:   False
# Operational:  True          Operational:  True           Operational:  True
# Avg. T1:      74.3          Avg. T1:      97.0           Avg. T1:      61.6
# Avg. T2:      58.2          Avg. T2:      83.8           Avg. T2:      47.0
#
#
#
# ibmq_16_melbourne
# -----------------
# Num. Qubits:  14
# Pending Jobs: 9
# Least busy:   False
# Operational:  False
# Avg. T1:      54.2
# Avg. T2:      74.9

# %%
real_backend = provider.get_backend('ibmq_16_melbourne')

# %%
backend_monitor(real_backend)
# Out:
# ibmq_16_melbourne
# =================
# Configuration
# -------------
#     n_qubits: 14
#     operational: False
#     status_msg: maintenance
#     pending_jobs: 9
#     backend_version: 1.0.0
#     basis_gates: ['u1', 'u2', 'u3', 'cx', 'id']
#     local: False
#     simulator: False
#     max_shots: 8192
#     max_experiments: 150
#     n_registers: 1
#     memory: False
#     allow_object_storage: True
#     allow_q_object: True
#     backend_name: ibmq_16_melbourne
#     conditional: False
#     sample_name: albatross
#     description: 14 qubit device
#     coupling_map: [[1, 0], [1, 2], [2, 3], [4, 3], [4, 10], [5, 4], [5, 6], [5, 9], [6, 8], [7, 8], [9, 8], [9, 10], [11, 3], [11, 10], [11, 12], [12, 2], [13, 1], [13, 12]]
#     open_pulse: False
#     online_date: 2018-11-06T05:00:00+00:00
#     url: None
#     allow_q_circuit: False
#     credits_required: True
#
# Qubits [Name / Freq / T1 / T2 / U1 err / U2 err / U3 err / Readout err]
# -----------------------------------------------------------------------
#     Q0 / 5.10014 GHz / 55.53076 µs / 22.11239 µs / 0.0 / 0.00216 / 0.00431 / 0.0407
#     Q1 / 5.23853 GHz / 67.96377 µs / 143.02894 µs / 0.0 / 0.00509 / 0.01017 / 0.058
#     Q2 / 5.0326 GHz / 76.05561 µs / 111.63941 µs / 0.0 / 0.00243 / 0.00486 / 0.095
#     Q3 / 4.89625 GHz / 63.42808 µs / 55.05287 µs / 0.0 / 0.00119 / 0.00238 / 0.0436
#     Q4 / 5.03072 GHz / 35.20991 µs / 18.03427 µs / 0.0 / 0.00471 / 0.00941 / 0.0603
#     Q5 / 5.06716 GHz / 27.12485 µs / 52.52769 µs / 0.0 / 0.00227 / 0.00453 / 0.063
#     Q6 / 4.92384 GHz / 76.20171 µs / 82.08915 µs / 0.0 / 0.00133 / 0.00267 / 0.0364
#     Q7 / 4.97456 GHz / 37.39406 µs / 71.7147 µs / 0.0 / 0.00246 / 0.00492 / 0.1117
#     Q8 / 4.73955 GHz / 58.32812 µs / 91.51486 µs / 0.0 / 0.00193 / 0.00385 / 0.0536
#     Q9 / 4.96337 GHz / 48.78864 µs / 85.43069 µs / 0.0 / 0.0184 / 0.03679 / 0.0247
#     Q10 / 4.94506 GHz / 53.7481 µs / 56.97521 µs / 0.0 / 0.11908 / 0.23816 / 0.1139
#     Q11 / 5.00501 GHz / 58.83398 µs / 110.76344 µs / 0.0 / 0.0015 / 0.003 / 0.0383
#     Q12 / 4.76009 GHz / 77.10462 µs / 111.80408 µs / 0.0 / 0.00378 / 0.00757 / 0.0856
#     Q13 / 4.96853 GHz / 23.41926 µs / 35.95415 µs / 0.0 / 0.00607 / 0.01215 / 0.0624
#
# Multi-Qubit Gates [Name / Type / Gate Error]
# --------------------------------------------
#     cx1_0 / cx / 0.03705
#     cx1_2 / cx / 0.03467
#     cx2_3 / cx / 0.04787
#     cx4_3 / cx / 0.06434
#     cx4_10 / cx / 0.11772
#     cx5_4 / cx / 0.1045
#     cx5_6 / cx / 0.05672
#     cx5_9 / cx / 0.0642
#     cx6_8 / cx / 0.03448
#     cx7_8 / cx / 0.02917
#     cx9_8 / cx / 0.18538
#     cx9_10 / cx / 0.1652
#     cx11_3 / cx / 0.03226
#     cx11_10 / cx / 0.03111
#     cx11_12 / cx / 0.06347
#     cx12_2 / cx / 0.08019
#     cx13_1 / cx / 0.15489
#     cx13_12 / cx / 0.04851

# %%
plot_error_map(real_backend)

# %%
qr = QuantumRegister(3)
cr = ClassicalRegister(3)
circuit = QuantumCircuit(qr, cr)

circuit.h(qr[0])
circuit.cx(qr[0], qr[2])
circuit.measure(qr, cr)

circuit.draw(output='mpl')

# %%
compiled_circuit = transpile(circuit, real_backend, optimization_level=3)
compiled_circuit.draw(output='mpl', idle_wires=False)

# %% [markdown]
# Transpilation (re-writing circuits) versus compilation (circuit into set of pulses)

# %%
#Transpilation on any backend (by providing custom coupling map)
from qiskit.transpiler import CouplingMap

compiled_circuit_custom_backend = transpile(circuit, coupling_map=CouplingMap([[1, 2],[1, 0]]))
#EXERCISE: Check if analogy to Melbourne connections will produce the same circuit

compiled_circuit_custom_backend.draw(output='mpl', idle_wires=False)

# %% [markdown]
# ## Transpiler optimization levels

# %%
#The default optimization level is 1.
#The bigger level, the heavier optimization (as you can see)
#EXERCISE - check level 2 or 3. These benefit from backend properties!!!
compiled_circuit = transpile(circuit, real_backend, optimization_level=0)
compiled_circuit.draw(output='mpl', idle_wires=False)
# Out:
# INFO:qiskit.transpiler.runningpassmanager:Pass: SetLayout - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: TrivialLayout - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ApplyLayout - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CheckMap - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: BarrierBeforeFinalMeasurements - 0.00000 (ms)
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:StochasticSwap default_rng seeded with seed=507104623
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:schedule:
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    0: [[Qubit(QuantumRegister(15, 'q'), 0)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    1: [[Qubit(QuantumRegister(15, 'q'), 0), Qubit(QuantumRegister(15, 'q'), 2)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    2: []
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    3: [[Qubit(QuantumRegister(15, 'q'), 1)], [Qubit(QuantumRegister(15, 'q'), 0)], [Qubit(QuantumRegister(15, 'q'), 2)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:trivial_layout = Layout({
# 0: Qubit(QuantumRegister(15, 'q'), 0),
# 1: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layer_partition = [[Qubit(QuantumRegister(15, 'q'), 0)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layout = {Qubit(QuantumRegister(15, 'q'), 0): 0, Qubit(QuantumRegister(15, 'q'), 1): 1, Qubit(QuantumRegister(15, 'q'), 2): 2, Qubit(QuantumRegister(15, 'q'), 3): 3, Qubit(QuantumRegister(15, 'q'), 4): 4, Qubit(QuantumRegister(15, 'q'), 5): 5, Qubit(QuantumRegister(15, 'q'), 6): 6, Qubit(QuantumRegister(15, 'q'), 7): 7, Qubit(QuantumRegister(15, 'q'), 8): 8, Qubit(QuantumRegister(15, 'q'), 9): 9, Qubit(QuantumRegister(15, 'q'), 10): 10, Qubit(QuantumRegister(15, 'q'), 11): 11, Qubit(QuantumRegister(15, 'q'), 12): 12, Qubit(QuantumRegister(15, 'q'), 13): 13, Qubit(QuantumRegister(15, 'q'), 14): 14}
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: qubit_subset = dict_keys([Qubit(QuantumRegister(15, 'q'), 0), Qubit(QuantumRegister(15, 'q'), 1), Qubit(QuantumRegister(15, 'q'), 2), Qubit(QuantumRegister(15, 'q'), 3), Qubit(QuantumRegister(15, 'q'), 4), Qubit(QuantumRegister(15, 'q'), 5), Qubit(QuantumRegister(15, 'q'), 6), Qubit(QuantumRegister(15, 'q'), 7), Qubit(QuantumRegister(15, 'q'), 8), Qubit(QuantumRegister(15, 'q'), 9), Qubit(QuantumRegister(15, 'q'), 10), Qubit(QuantumRegister(15, 'q'), 11), Qubit(QuantumRegister(15, 'q'), 12), Qubit(QuantumRegister(15, 'q'), 13), Qubit(QuantumRegister(15, 'q'), 14)])
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: trials = 20
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: gates = []
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: distance = 0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: nothing to do
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: layer 0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: success_flag=True,best_depth=0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: layout = Layout({
# 0: Qubit(QuantumRegister(15, 'q'), 0),
# 1: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: self.trivial_layout = Layout({
# 0: Qubit(QuantumRegister(15, 'q'), 0),
# 1: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: there are no swaps in this layer
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layer_partition = [[Qubit(QuantumRegister(15, 'q'), 0), Qubit(QuantumRegister(15, 'q'), 2)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layout = {Qubit(QuantumRegister(15, 'q'), 0): 0, Qubit(QuantumRegister(15, 'q'), 1): 1, Qubit(QuantumRegister(15, 'q'), 2): 2, Qubit(QuantumRegister(15, 'q'), 3): 3, Qubit(QuantumRegister(15, 'q'), 4): 4, Qubit(QuantumRegister(15, 'q'), 5): 5, Qubit(QuantumRegister(15, 'q'), 6): 6, Qubit(QuantumRegister(15, 'q'), 7): 7, Qubit(QuantumRegister(15, 'q'), 8): 8, Qubit(QuantumRegister(15, 'q'), 9): 9, Qubit(QuantumRegister(15, 'q'), 10): 10, Qubit(QuantumRegister(15, 'q'), 11): 11, Qubit(QuantumRegister(15, 'q'), 12): 12, Qubit(QuantumRegister(15, 'q'), 13): 13, Qubit(QuantumRegister(15, 'q'), 14): 14}
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: qubit_subset = dict_keys([Qubit(QuantumRegister(15, 'q'), 0), Qubit(QuantumRegister(15, 'q'), 1), Qubit(QuantumRegister(15, 'q'), 2), Qubit(QuantumRegister(15, 'q'), 3), Qubit(QuantumRegister(15, 'q'), 4), Qubit(QuantumRegister(15, 'q'), 5), Qubit(QuantumRegister(15, 'q'), 6), Qubit(QuantumRegister(15, 'q'), 7), Qubit(QuantumRegister(15, 'q'), 8), Qubit(QuantumRegister(15, 'q'), 9), Qubit(QuantumRegister(15, 'q'), 10), Qubit(QuantumRegister(15, 'q'), 11), Qubit(QuantumRegister(15, 'q'), 12), Qubit(QuantumRegister(15, 'q'), 13), Qubit(QuantumRegister(15, 'q'), 14)])
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: trials = 20
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: gates = [(Qubit(QuantumRegister(15, 'q'), 0), Qubit(QuantumRegister(15, 'q'), 2))]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: distance = 2
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: trial 0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: final distance for this trial = 1.0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: got circuit with improved depth 1
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: success!
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: layer 1
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: success_flag=True,best_depth=1
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: layout = Layout({
# 1: Qubit(QuantumRegister(15, 'q'), 0),
# 0: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: self.trivial_layout = Layout({
# 0: Qubit(QuantumRegister(15, 'q'), 0),
# 1: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: there are swaps in this layer, depth 1
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layer_partition = []
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layout = {Qubit(QuantumRegister(15, 'q'), 0): 1, Qubit(QuantumRegister(15, 'q'), 1): 0, Qubit(QuantumRegister(15, 'q'), 2): 2, Qubit(QuantumRegister(15, 'q'), 3): 3, Qubit(QuantumRegister(15, 'q'), 4): 4, Qubit(QuantumRegister(15, 'q'), 5): 5, Qubit(QuantumRegister(15, 'q'), 6): 6, Qubit(QuantumRegister(15, 'q'), 7): 7, Qubit(QuantumRegister(15, 'q'), 8): 8, Qubit(QuantumRegister(15, 'q'), 9): 9, Qubit(QuantumRegister(15, 'q'), 10): 10, Qubit(QuantumRegister(15, 'q'), 11): 11, Qubit(QuantumRegister(15, 'q'), 12): 12, Qubit(QuantumRegister(15, 'q'), 13): 13, Qubit(QuantumRegister(15, 'q'), 14): 14}
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: qubit_subset = dict_keys([Qubit(QuantumRegister(15, 'q'), 0), Qubit(QuantumRegister(15, 'q'), 1), Qubit(QuantumRegister(15, 'q'), 2), Qubit(QuantumRegister(15, 'q'), 3), Qubit(QuantumRegister(15, 'q'), 4), Qubit(QuantumRegister(15, 'q'), 5), Qubit(QuantumRegister(15, 'q'), 6), Qubit(QuantumRegister(15, 'q'), 7), Qubit(QuantumRegister(15, 'q'), 8), Qubit(QuantumRegister(15, 'q'), 9), Qubit(QuantumRegister(15, 'q'), 10), Qubit(QuantumRegister(15, 'q'), 11), Qubit(QuantumRegister(15, 'q'), 12), Qubit(QuantumRegister(15, 'q'), 13), Qubit(QuantumRegister(15, 'q'), 14)])
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: trials = 20
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: gates = []
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: distance = 0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: nothing to do
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: layer 2
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: success_flag=True,best_depth=0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: layout = Layout({
# 1: Qubit(QuantumRegister(15, 'q'), 0),
# 0: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: self.trivial_layout = Layout({
# 0: Qubit(QuantumRegister(15, 'q'), 0),
# 1: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: there are no swaps in this layer
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layer_partition = [[Qubit(QuantumRegister(15, 'q'), 1)], [Qubit(QuantumRegister(15, 'q'), 0)], [Qubit(QuantumRegister(15, 'q'), 2)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layout = {Qubit(QuantumRegister(15, 'q'), 0): 1, Qubit(QuantumRegister(15, 'q'), 1): 0, Qubit(QuantumRegister(15, 'q'), 2): 2, Qubit(QuantumRegister(15, 'q'), 3): 3, Qubit(QuantumRegister(15, 'q'), 4): 4, Qubit(QuantumRegister(15, 'q'), 5): 5, Qubit(QuantumRegister(15, 'q'), 6): 6, Qubit(QuantumRegister(15, 'q'), 7): 7, Qubit(QuantumRegister(15, 'q'), 8): 8, Qubit(QuantumRegister(15, 'q'), 9): 9, Qubit(QuantumRegister(15, 'q'), 10): 10, Qubit(QuantumRegister(15, 'q'), 11): 11, Qubit(QuantumRegister(15, 'q'), 12): 12, Qubit(QuantumRegister(15, 'q'), 13): 13, Qubit(QuantumRegister(15, 'q'), 14): 14}
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: qubit_subset = dict_keys([Qubit(QuantumRegister(15, 'q'), 0), Qubit(QuantumRegister(15, 'q'), 1), Qubit(QuantumRegister(15, 'q'), 2), Qubit(QuantumRegister(15, 'q'), 3), Qubit(QuantumRegister(15, 'q'), 4), Qubit(QuantumRegister(15, 'q'), 5), Qubit(QuantumRegister(15, 'q'), 6), Qubit(QuantumRegister(15, 'q'), 7), Qubit(QuantumRegister(15, 'q'), 8), Qubit(QuantumRegister(15, 'q'), 9), Qubit(QuantumRegister(15, 'q'), 10), Qubit(QuantumRegister(15, 'q'), 11), Qubit(QuantumRegister(15, 'q'), 12), Qubit(QuantumRegister(15, 'q'), 13), Qubit(QuantumRegister(15, 'q'), 14)])
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: trials = 20
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: gates = []
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: distance = 0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: nothing to do
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: layer 3
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: success_flag=True,best_depth=0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: layout = Layout({
# 1: Qubit(QuantumRegister(15, 'q'), 0),
# 0: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: self.trivial_layout = Layout({
# 0: Qubit(QuantumRegister(15, 'q'), 0),
# 1: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: there are no swaps in this layer
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: self.trivial_layout = Layout({
# 0: Qubit(QuantumRegister(15, 'q'), 0),
# 1: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: layout = Layout({
# 1: Qubit(QuantumRegister(15, 'q'), 0),
# 0: Qubit(QuantumRegister(15, 'q'), 1),
# 2: Qubit(QuantumRegister(15, 'q'), 2),
# 3: Qubit(QuantumRegister(15, 'q'), 3),
# 4: Qubit(QuantumRegister(15, 'q'), 4),
# 5: Qubit(QuantumRegister(15, 'q'), 5),
# 6: Qubit(QuantumRegister(15, 'q'), 6),
# 7: Qubit(QuantumRegister(15, 'q'), 7),
# 8: Qubit(QuantumRegister(15, 'q'), 8),
# 9: Qubit(QuantumRegister(15, 'q'), 9),
# 10: Qubit(QuantumRegister(15, 'q'), 10),
# 11: Qubit(QuantumRegister(15, 'q'), 11),
# 12: Qubit(QuantumRegister(15, 'q'), 12),
# 13: Qubit(QuantumRegister(15, 'q'), 13),
# 14: Qubit(QuantumRegister(15, 'q'), 14)
# })
# INFO:qiskit.transpiler.runningpassmanager:Pass: StochasticSwap - 139.34684 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO:qiskit.transpiler.passes.basis.basis_translator:Begin BasisTranslator from source basis {('swap', 2), ('h', 1), ('cx', 2), ('measure', 1), ('barrier', 15)} to target basis {'id', 'u2', 'u3', 'snapshot', 'u1', 'measure', 'reset', 'barrier', 'cx'}.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Begining basis search from frozenset({('cx', 2), ('measure', 1), ('barrier', 15), ('swap', 2), ('h', 1)}) to frozenset({'barrier', 'id', 'snapshot', 'u2', 'u1', 'measure', 'reset', 'u3', 'cx'}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('cx', 2), ('measure', 1), ('barrier', 15), ('swap', 2), ('h', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('u2', 1), ('cx', 2), ('measure', 1), ('barrier', 15), ('swap', 2)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Transformation path:
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:h/1 => []
#      ┌──────────┐
# q_0: ┤ U2(0,pi) ├
#      └──────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:swap/2 => []
#           ┌───┐
# q_0: ──■──┤ X ├──■──
#      ┌─┴─┐└─┬─┘┌─┴─┐
# q_1: ┤ X ├──■──┤ X ├
#      └───┘     └───┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation path search completed in 0.013s.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: h/1 [] =>
#      ┌──────────┐
# q_0: ┤ U2(0,pi) ├
#      └──────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('h', 1) h, [] from
#         ┌───┐
# q113_0: ┤ h ├
#         └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('h', 1) h, [] to
#         ┌──────────┐
# q113_0: ┤ U2(0,pi) ├
#         └──────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: swap/2 [] =>
#           ┌───┐
# q_0: ──■──┤ X ├──■──
#      ┌─┴─┐└─┬─┘┌─┴─┐
# q_1: ┤ X ├──■──┤ X ├
#      └───┘     └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('swap', 2) swap, [] from
#         ┌───────┐
# q112_0: ┤0      ├
#         │  swap │
# q112_1: ┤1      ├
#         └───────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('swap', 2) swap, [] to
#              ┌───┐
# q112_0: ──■──┤ X ├──■──
#         ┌─┴─┐└─┬─┘┌─┴─┐
# q112_1: ┤ X ├──■──┤ X ├
#         └───┘     └───┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation paths composed in 0.024s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation instructions replaced in 0.001s.
# INFO:qiskit.transpiler.runningpassmanager:Pass: BasisTranslator - 56.00238 (ms)
# INFO:qiskit.compiler.transpile:Total Transpile Time - 217.97562 (ms)

# %% [markdown]
# As can be seen, BackendProperties taken from backend allowed to choose optimal two qubits (with smallest errors), not just random two connected with each other.
#
# Providing backend is optional. One can compile for any topology specified as input to transpiler.

# %% [markdown]
# * `optimization_level=0`: just maps the circuit to the backend, with no explicit optimization (except whatever optimizations the mapper does)
#
# * `optimization_level=1`: maps the circuit, but also does light-weight optimizations by collapsing adjacent gates.
#
# * `optimization_level=2`: medium-weight optimization, including a noise-adaptive layout and a gate-cancellation procedure based on gate commutation relationships.
#
# * `optimization_level=3`: heavy-weight optimization, which in addition to previous steps, does resynthesis of two-qubit blocks of gates in the circuit.

# %% [markdown]
# Transpiler uses predefined so called PassManager (depending on optimization level). However, one can use a custom PassManager which will be tuned for certain applications.

# %%
#Now let's do something more dificult:

qr2 = QuantumRegister(14)
cr2 = ClassicalRegister(14)
circuit2 = QuantumCircuit(qr2, cr2)

circuit2.h(qr2[0])
circuit2.cx(qr2[0], qr2[6])
circuit2.cx(qr2[6], qr2[13])
circuit2.cx(qr2[13], qr2[7])
circuit2.cx(qr2[7], qr2[0])
circuit2.measure(qr2, cr2)

circuit2.draw(output='mpl')

# %%
for level in range(4):
    compiled_circuit2 = transpile(circuit2, real_backend, optimization_level=level)
    print('---------- Level = ' + str(level) + '----------')
    print('gates = ', compiled_circuit2.count_ops())
    print('depth = ', compiled_circuit2.depth())
# Out:
# ---------- Level = 0----------
# gates =  OrderedDict([('cx', 43), ('measure', 14), ('u2', 1), ('barrier', 1)])
# depth =  26
# ---------- Level = 1----------
# gates =  OrderedDict([('cx', 31), ('measure', 14), ('u2', 1), ('barrier', 1)])
# depth =  21
# ---------- Level = 2----------
# gates =  OrderedDict([('measure', 14), ('cx', 4), ('u2', 1)])
# depth =  6
# ---------- Level = 3----------
# gates =  OrderedDict([('measure', 14), ('cx', 4), ('u2', 1)])
# depth =  6

# %%
compiled_circuit2 = transpile(circuit2, real_backend, optimization_level=2)
compiled_circuit2.draw(output='mpl', idle_wires=False)

# %% [markdown]
# ## What transpiler does?

# %%
import logging
#logging.basicConfig(level='DEBUG')
logging.basicConfig(level='INFO')

# %%
import logging

#logging.getLogger('qiskit.transpiler').setLevel('INFO')
transpile(circuit, real_backend, optimization_level=3)

#EXERCISE: check logging on various optimization levels
# Out:
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: OptimizeSwapBeforeMeasure - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveDiagonalGatesBeforeMeasure - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: SetLayout - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CSPLayout - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ApplyLayout - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CheckMap - 15.62428 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO:qiskit.transpiler.passes.basis.basis_translator:Begin BasisTranslator from source basis {('measure', 1), ('cx', 2), ('h', 1)} to target basis {'id', 'u2', 'u3', 'snapshot', 'u1', 'measure', 'reset', 'barrier', 'cx'}.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Begining basis search from frozenset({('measure', 1), ('cx', 2), ('h', 1)}) to frozenset({'barrier', 'id', 'snapshot', 'u2', 'u1', 'measure', 'reset', 'u3', 'cx'}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('measure', 1), ('cx', 2), ('h', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Transformation path:
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:h/1 => []
#      ┌──────────┐
# q_0: ┤ U2(0,pi) ├
#      └──────────┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation path search completed in 0.000s.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: h/1 [] =>
#      ┌──────────┐
# q_0: ┤ U2(0,pi) ├
#      └──────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('h', 1) h, [] from
#        ┌───┐
# q74_0: ┤ h ├
#        └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('h', 1) h, [] to
#        ┌──────────┐
# q74_0: ┤ U2(0,pi) ├
#        └──────────┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation paths composed in 0.016s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation instructions replaced in 0.000s.
# INFO:qiskit.transpiler.runningpassmanager:Pass: BasisTranslator - 31.25787 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Collect2qBlocks - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ConsolidateBlocks - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: UnitarySynthesis - 6.51860 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutationAnalysis - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutativeCancellation - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO:qiskit.transpiler.passes.basis.basis_translator:Begin BasisTranslator from source basis {('measure', 1), ('cx', 2), ('u2', 1)} to target basis {'id', 'u2', 'u3', 'snapshot', 'u1', 'measure', 'reset', 'barrier', 'cx'}.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Begining basis search from frozenset({('measure', 1), ('cx', 2), ('u2', 1)}) to frozenset({'barrier', 'id', 'snapshot', 'u2', 'u1', 'measure', 'reset', 'u3', 'cx'}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Transformation path:
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation path search completed in 0.000s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation paths composed in 0.000s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation instructions replaced in 0.000s.
# INFO:qiskit.transpiler.runningpassmanager:Pass: BasisTranslator - 15.64384 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Collect2qBlocks - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ConsolidateBlocks - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: UnitarySynthesis - 15.62381 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutationAnalysis - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutativeCancellation - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: UnrollCustomDefinitions - 0.00000 (ms)
# INFO:qiskit.transpiler.passes.basis.basis_translator:Begin BasisTranslator from source basis {('measure', 1), ('cx', 2), ('u2', 1)} to target basis {'id', 'u2', 'u3', 'snapshot', 'u1', 'measure', 'reset', 'barrier', 'cx'}.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Begining basis search from frozenset({('measure', 1), ('cx', 2), ('u2', 1)}) to frozenset({'barrier', 'id', 'snapshot', 'u2', 'u1', 'measure', 'reset', 'u3', 'cx'}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Transformation path:
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation path search completed in 0.000s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation paths composed in 0.000s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation instructions replaced in 0.000s.
# INFO:qiskit.transpiler.runningpassmanager:Pass: BasisTranslator - 15.62738 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO:qiskit.compiler.transpile:Total Transpile Time - 147.18771 (ms)

# %% [markdown]
# Transpiler uses Pass Manager to do a set of passes transforming the circuit until the final shape.

# %%
#Getting info about all existing transpiler passes:

from qiskit.transpiler import passes
for passitem in dir(passes):
    if passitem[0].isupper(): print(passitem)
# Out:
# ApplyLayout
# BarrierBeforeFinalMeasurements
# BasicSwap
# BasisTranslator
# CSPLayout
# CXCancellation
# CXDirection
# CheckCXDirection
# CheckMap
# Collect2qBlocks
# CommutationAnalysis
# CommutativeCancellation
# ConsolidateBlocks
# CountOps
# CountOpsLongestPath
# CrosstalkAdaptiveSchedule
# DAGFixedPoint
# DAGLongestPath
# Decompose
# DenseLayout
# Depth
# EnlargeWithAncilla
# FixedPoint
# FullAncillaAllocation
# HoareOptimizer
# Layout2qDistance
# LayoutTransformation
# LookaheadSwap
# MergeAdjacentBarriers
# NoiseAdaptiveLayout
# NumTensorFactors
# Optimize1qGates
# OptimizeSwapBeforeMeasure
# RemoveDiagonalGatesBeforeMeasure
# RemoveFinalMeasurements
# RemoveResetInZeroState
# ResourceEstimation
# SabreLayout
# SabreSwap
# SetLayout
# Size
# StochasticSwap
# TrivialLayout
# UnitarySynthesis
# Unroll3qOrMore
# UnrollCustomDefinitions
# Unroller
# Width

# %% [markdown]
# Passes can be transformation passes or analysis passes.

# %% [markdown]
# ## How to use custom transpiler (custom pass manager)?
# ### Example: expressing desired circuit using only natively implemented gates: Unroller

# %%
from qiskit.transpiler.passes import Unroller

# PassManager(passes=None, max_iteration=None, callback=None)
pm = PassManager(Unroller(['u1', 'cx']))
# EXERCISE: If one would have a backend with natively implemented H gate, it can be provided to Unroller.

new_circuit = pm.run(circuit)
new_circuit.draw(output='mpl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\qiskit\transpiler\passes\basis\unroller.py in run(self, dag)
#      84                 try:
# ---> 85                     rule = rule[0][0].definition.data
#      86                 except (TypeError, AttributeError) as err:
#
# AttributeError: 'NoneType' object has no attribute 'data'
#
# During handling of the above exception, another exception occurred:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-17-3b5fed795117> in <module>
#       5 # EXERCISE: If one would have a backend with natively implemented H gate, it can be provided to Unroller.
#       6
# ----> 7 new_circuit = pm.run(circuit)
#       8 new_circuit.draw(output='mpl')
#
# C:\Anaconda3\lib\site-packages\qiskit\transpiler\passmanager.py in run(self, circuits, output_name, callback)
#     212         """
#     213         if isinstance(circuits, QuantumCircuit):
# --> 214             return self._run_single_circuit(circuits, output_name, callback)
#     215         elif len(circuits) == 1:
#     216             return self._run_single_circuit(circuits[0], output_name, callback)
#
# C:\Anaconda3\lib\site-packages\qiskit\transpiler\passmanager.py in _run_single_circuit(self, circuit, output_name, callback)
#     275         if callback is None and self.callback:  # TODO to remove with __init__(callback)
#     276             callback = self.callback
# --> 277         result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     278         self.property_set = running_passmanager.property_set
#     279         return result
#
# C:\Anaconda3\lib\site-packages\qiskit\transpiler\runningpassmanager.py in run(***failed resolving arguments***)
#     113         for passset in self.working_list:
#     114             for pass_ in passset:
# --> 115                 dag = self._do_pass(pass_, dag, passset.options)
#     116
#     117         circuit = dag_to_circuit(dag)
#
# C:\Anaconda3\lib\site-packages\qiskit\transpiler\runningpassmanager.py in _do_pass(self, pass_, dag, options)
#     143         # Run the pass itself, if not already run
#     144         if pass_ not in self.valid_passes:
# --> 145             dag = self._run_this_pass(pass_, dag)
#     146
#     147             # update the valid_passes property
#
# C:\Anaconda3\lib\site-packages\qiskit\transpiler\runningpassmanager.py in _run_this_pass(self, pass_, dag)
#     155             # Measure time if we have a callback or logging set
#     156             start_time = time()
# --> 157             new_dag = pass_.run(dag)
#     158             end_time = time()
#     159             run_time = end_time - start_time
#
# C:\Anaconda3\lib\site-packages\qiskit\transpiler\passes\basis\unroller.py in run(self, dag)
#      85                     rule = rule[0][0].definition.data
#      86                 except (TypeError, AttributeError) as err:
# ---> 87                     raise QiskitError('Error decomposing node {}: {}'.format(node.name, err))
#      88
#      89             else:
#
# QiskitError: "Error decomposing node h: 'NoneType' object has no attribute 'data'"

# %% [markdown]
# ## How Pass Manager works under the cover?

# %% [markdown]
# In Qiskit, we represent circuits internally using a Directed Acyclic Graph (DAG).
#
# Each pass can either analyze the circuit and write conclusions in a commonly accessible properties or transform the circuit by using the properties from analysis (in read-only mode)

# %%
dag = circuit_to_dag(circuit2)
dag_drawer(dag)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\qiskit\visualization\dag_visualization.py in dag_drawer(dag, scale, filename, style)
#      84     try:
# ---> 85         import pydot  # pylint: disable=unused-import
#      86     except ImportError:
#
# ModuleNotFoundError: No module named 'pydot'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-63b5b884bad8> in <module>
#       1 dag = circuit_to_dag(circuit2)
# ----> 2 dag_drawer(dag)
#
# C:\Anaconda3\lib\site-packages\qiskit\visualization\dag_visualization.py in dag_drawer(dag, scale, filename, style)
#      85         import pydot  # pylint: disable=unused-import
#      86     except ImportError:
# ---> 87         raise ImportError("dag_drawer requires pydot. "
#      88                           "Run 'pip install pydot'.")
#      89     # NOTE: use type str checking to avoid potential cyclical import
#
# ImportError: dag_drawer requires pydot. Run 'pip install pydot'.

# %% [markdown]
# Three kinds of graph nodes exist: qubit/clbit input nodes (green), operation nodes (blue), and output nodes (red). Each edge indicates data flow (or dependency) between two nodes.

# %%
from qiskit.transpiler.passes import Unroller

pm = PassManager()
pm.append(Unroller(['id','u1','h','u3','cx']))
new_circuit = pm.run(circuit)
dag = circuit_to_dag(new_circuit)
dag_drawer(dag)

# %%
qr = QuantumRegister(3)
cr = ClassicalRegister(3)
circuit3 = QuantumCircuit(qr, cr)

circuit3.ccx(qr[0], qr[1], qr[2])
circuit3.measure(qr, cr)

circuit3.draw(output='mpl')

new_circuit3 = pm.run(circuit3)
dag_drawer(circuit_to_dag(new_circuit3))
new_circuit3.count_ops()
# Out:
# OrderedDict([('u1', 7), ('cx', 6), ('measure', 3), ('h', 2)])

# %%
from qiskit.transpiler.passes import Depth

pm.append(Depth())
new_circuit = pm.run(circuit)

pm.property_set
# Out:
# {'depth': 3}
